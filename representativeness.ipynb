# %%
import os
import json
import numpy as np
import pandas as pd
from scipy.stats import wasserstein_distance
import helpers as ph
import seaborn as sns
import dataframe_image as dfi

COLOR_STR = "#0A3EA4,#4874F9,#84A0F5,#F1F4FB,#FFFFFF"
palette = sns.color_palette(f"blend:{COLOR_STR}", 12, as_cmap=True)

styles = ph.VIS_STYLES

# %%
RESULTS_DIR = f'./data/distributions/'
CONTEXT = 'default'
SAVEFIG = False

# %% [markdown]
# ## Load human and LM opinion distributions

# %%
combined_df, human_df = [], []
for wave in ph.PEW_SURVEY_LIST:
    SURVEY_NAME = f'American_Trends_Panel_W{wave}'

    cdf = pd.read_csv(os.path.join(RESULTS_DIR, f'{SURVEY_NAME}_{CONTEXT}_combined.csv'))
    cdf['survey'] = f'ATP {wave}'
    combined_df.append(cdf)
    
    hdf = pd.read_csv(os.path.join(RESULTS_DIR, f'{SURVEY_NAME}_{CONTEXT}_baseline.csv'))
    hdf['survey'] = f'ATP {wave}'
    human_df.append(hdf)
combined_df, human_df = pd.concat(combined_df), pd.concat(human_df)
combined_df['Source'] = combined_df.apply(lambda x: 'AI21 Labs' if 'j1-' in x['model_name'].lower() else 'OpenAI',
                                          axis=1)

# %%
print('# Questions:', len(set(combined_df['question'])))
# Out:
# # Questions: 1498

# %% [markdown]
# ## Compute average representativeness across dataset

# %%
KEYS = ['Source', 'model_name', 'attribute', 'group', 'group_order', 'model_order']

grouped = combined_df.groupby(KEYS, as_index=False).agg({'WD': np.mean}) \
         .sort_values(by=['model_order', 'group_order'])
grouped['Rep'] = 1 - grouped['WD']
# Out:
# /tmp/ipykernel_3469/2248436706.py:3: FutureWarning: The provided callable <function mean at 0x7f92d45339c0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped = combined_df.groupby(KEYS, as_index=False).agg({'WD': np.mean}) \

# %% [markdown]
# ### Overall representativeness

# %%
human_baseline = human_df.groupby(['group_x'], as_index=False).agg({'WD': np.mean})
human_baseline['Rep'] = 1 - human_baseline['WD']
human_baseline = human_baseline.agg({'Rep': (np.mean, min)}).reset_index()
human_baseline['model_name'] = human_baseline.apply(lambda x: 'Avg' if x['index'] == 'mean' \
                                                    else 'Worst', axis=1)
human_baseline['model_order'] = -1
human_baseline['Source'] = "Humans"


g = pd.concat([human_baseline, grouped[grouped['attribute'] == 'Overall']]).rename(columns={'model_name': '',
                                                                                            'Rep': 'R'})

table = pd.pivot_table(g, 
                       columns=['Source', ''], 
                       values='R', 
                       sort=False)
table_vis = table.style.background_gradient(palette, axis=1).set_table_styles(styles)  \
                        .set_properties(**{"font-size":"0.75rem"}).format(precision=3)

if SAVEFIG: table_vis.hide_index().export_png('./figures/representativeness.png')
display(table_vis)
# Out:
# /tmp/ipykernel_3469/1550611425.py:1: FutureWarning: The provided callable <function mean at 0x7f92d45339c0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   human_baseline = human_df.groupby(['group_x'], as_index=False).agg({'WD': np.mean})
# /tmp/ipykernel_3469/1550611425.py:3: FutureWarning: The provided callable <function mean at 0x7f92d45339c0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   human_baseline = human_baseline.agg({'Rep': (np.mean, min)}).reset_index()
# /tmp/ipykernel_3469/1550611425.py:3: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   human_baseline = human_baseline.agg({'Rep': (np.mean, min)}).reset_index()
# <style type="text/css">
# #T_33213 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_33213 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_33213 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_33213 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 70%;
# }
# #T_33213_row0_col0 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col1 {
#   background-color: #cdd8f9;
#   color: #000000;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col2 {
#   background-color: #7897f6;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col3 {
#   background-color: #7b99f6;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col4 {
#   background-color: #7091f6;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col5 {
#   background-color: #84a0f5;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col6 {
#   background-color: #6488f7;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col7 {
#   background-color: #1043ac;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col8 {
#   background-color: #184ab7;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col9 {
#   background-color: #4773f8;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# #T_33213_row0_col10 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 0.75rem;
# }
# </style>
# <table id="T_33213">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_33213_level0_col0" class="col_heading level0 col0" colspan="2">Humans</th>
#       <th id="T_33213_level0_col2" class="col_heading level0 col2" colspan="3">AI21 Labs</th>
#       <th id="T_33213_level0_col5" class="col_heading level0 col5" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_33213_level1_col0" class="col_heading level1 col0" >Avg</th>
#       <th id="T_33213_level1_col1" class="col_heading level1 col1" >Worst</th>
#       <th id="T_33213_level1_col2" class="col_heading level1 col2" >j1-grande</th>
#       <th id="T_33213_level1_col3" class="col_heading level1 col3" >j1-jumbo</th>
#       <th id="T_33213_level1_col4" class="col_heading level1 col4" >j1-grande-v2-beta</th>
#       <th id="T_33213_level1_col5" class="col_heading level1 col5" >ada</th>
#       <th id="T_33213_level1_col6" class="col_heading level1 col6" >davinci</th>
#       <th id="T_33213_level1_col7" class="col_heading level1 col7" >text-ada-001</th>
#       <th id="T_33213_level1_col8" class="col_heading level1 col8" >text-davinci-001</th>
#       <th id="T_33213_level1_col9" class="col_heading level1 col9" >text-davinci-002</th>
#       <th id="T_33213_level1_col10" class="col_heading level1 col10" >text-davinci-003</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33213_level0_row0" class="row_heading level0 row0" >R</th>
#       <td id="T_33213_row0_col0" class="data row0 col0" >0.949</td>
#       <td id="T_33213_row0_col1" class="data row0 col1" >0.867</td>
#       <td id="T_33213_row0_col2" class="data row0 col2" >0.814</td>
#       <td id="T_33213_row0_col3" class="data row0 col3" >0.817</td>
#       <td id="T_33213_row0_col4" class="data row0 col4" >0.806</td>
#       <td id="T_33213_row0_col5" class="data row0 col5" >0.826</td>
#       <td id="T_33213_row0_col6" class="data row0 col6" >0.793</td>
#       <td id="T_33213_row0_col7" class="data row0 col7" >0.710</td>
#       <td id="T_33213_row0_col8" class="data row0 col8" >0.717</td>
#       <td id="T_33213_row0_col9" class="data row0 col9" >0.764</td>
#       <td id="T_33213_row0_col10" class="data row0 col10" >0.703</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Subgroup representativeness

# %%
styles[-1]['props'][-1] = (styles[-1]['props'][-1][0], "105%")

# %%
for attribute in ph.DEMOGRAPHIC_ATTRIBUTES[1:]:
    
    print(f'-----{attribute}----')
    
    g = grouped[grouped['attribute'] == attribute].rename(columns={'model_name': 'Model', 'group': attribute,
                                                                  'Source': ''})

    table = pd.pivot_table(g, 
                           index=[attribute], 
                           columns=['', 'Model'], 
                           values="Rep", 
                           sort=False)
    table_vis = table.style.background_gradient(palette, axis=(attribute=='Overall')).set_table_styles(styles)  \
                            .set_properties(**{"font-size":"1.3rem"}).format(precision=3)
    if SAVEFIG: table_vis.export_png(f'./figures/representativeness_{attribute}.png')

    display(table_vis)
# Out:
# -----CREGION----
# <style type="text/css">
# #T_b5194 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_b5194 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_b5194 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_b5194 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_b5194_row0_col0, #T_b5194_row0_col3, #T_b5194_row1_col1, #T_b5194_row1_col2, #T_b5194_row1_col4, #T_b5194_row2_col6, #T_b5194_row2_col7, #T_b5194_row2_col8, #T_b5194_row3_col5 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row0_col1, #T_b5194_row1_col3 {
#   background-color: #2c5cd3;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row0_col2 {
#   background-color: #9bb2f6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_b5194_row0_col4 {
#   background-color: #4471f4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row0_col5 {
#   background-color: #6489f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row0_col6 {
#   background-color: #3765e1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row0_col7, #T_b5194_row0_col8, #T_b5194_row1_col5, #T_b5194_row2_col0, #T_b5194_row2_col1, #T_b5194_row2_col2, #T_b5194_row2_col3, #T_b5194_row2_col4, #T_b5194_row3_col6 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_b5194_row1_col0 {
#   background-color: #2152c4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row1_col6 {
#   background-color: #819ef5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row1_col7 {
#   background-color: #c4d1f9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_b5194_row1_col8 {
#   background-color: #b5c6f8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_b5194_row2_col5 {
#   background-color: #f6f8fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_b5194_row3_col0 {
#   background-color: #507af8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row3_col1 {
#   background-color: #6e90f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row3_col2 {
#   background-color: #b6c7f8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_b5194_row3_col3 {
#   background-color: #4673f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row3_col4 {
#   background-color: #7b99f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_b5194_row3_col7, #T_b5194_row3_col8 {
#   background-color: #fcfdfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_b5194">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_b5194_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_b5194_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_b5194_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_b5194_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_b5194_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_b5194_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_b5194_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_b5194_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_b5194_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_b5194_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_b5194_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CREGION</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5194_level0_row0" class="row_heading level0 row0" >Northeast</th>
#       <td id="T_b5194_row0_col0" class="data row0 col0" >0.809</td>
#       <td id="T_b5194_row0_col1" class="data row0 col1" >0.812</td>
#       <td id="T_b5194_row0_col2" class="data row0 col2" >0.803</td>
#       <td id="T_b5194_row0_col3" class="data row0 col3" >0.821</td>
#       <td id="T_b5194_row0_col4" class="data row0 col4" >0.789</td>
#       <td id="T_b5194_row0_col5" class="data row0 col5" >0.708</td>
#       <td id="T_b5194_row0_col6" class="data row0 col6" >0.716</td>
#       <td id="T_b5194_row0_col7" class="data row0 col7" >0.766</td>
#       <td id="T_b5194_row0_col8" class="data row0 col8" >0.707</td>
#     </tr>
#     <tr>
#       <th id="T_b5194_level0_row1" class="row_heading level0 row1" >Midwest</th>
#       <td id="T_b5194_row1_col0" class="data row1 col0" >0.810</td>
#       <td id="T_b5194_row1_col1" class="data row1 col1" >0.811</td>
#       <td id="T_b5194_row1_col2" class="data row1 col2" >0.799</td>
#       <td id="T_b5194_row1_col3" class="data row1 col3" >0.822</td>
#       <td id="T_b5194_row1_col4" class="data row1 col4" >0.788</td>
#       <td id="T_b5194_row1_col5" class="data row1 col5" >0.710</td>
#       <td id="T_b5194_row1_col6" class="data row1 col6" >0.717</td>
#       <td id="T_b5194_row1_col7" class="data row1 col7" >0.764</td>
#       <td id="T_b5194_row1_col8" class="data row1 col8" >0.703</td>
#     </tr>
#     <tr>
#       <th id="T_b5194_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_b5194_row2_col0" class="data row2 col0" >0.818</td>
#       <td id="T_b5194_row2_col1" class="data row2 col1" >0.820</td>
#       <td id="T_b5194_row2_col2" class="data row2 col2" >0.807</td>
#       <td id="T_b5194_row2_col3" class="data row2 col3" >0.828</td>
#       <td id="T_b5194_row2_col4" class="data row2 col4" >0.795</td>
#       <td id="T_b5194_row2_col5" class="data row2 col5" >0.710</td>
#       <td id="T_b5194_row2_col6" class="data row2 col6" >0.715</td>
#       <td id="T_b5194_row2_col7" class="data row2 col7" >0.761</td>
#       <td id="T_b5194_row2_col8" class="data row2 col8" >0.698</td>
#     </tr>
#     <tr>
#       <th id="T_b5194_level0_row3" class="row_heading level0 row3" >West</th>
#       <td id="T_b5194_row3_col0" class="data row3 col0" >0.811</td>
#       <td id="T_b5194_row3_col1" class="data row3 col1" >0.815</td>
#       <td id="T_b5194_row3_col2" class="data row3 col2" >0.804</td>
#       <td id="T_b5194_row3_col3" class="data row3 col3" >0.823</td>
#       <td id="T_b5194_row3_col4" class="data row3 col4" >0.791</td>
#       <td id="T_b5194_row3_col5" class="data row3 col5" >0.707</td>
#       <td id="T_b5194_row3_col6" class="data row3 col6" >0.718</td>
#       <td id="T_b5194_row3_col7" class="data row3 col7" >0.765</td>
#       <td id="T_b5194_row3_col8" class="data row3 col8" >0.706</td>
#     </tr>
#   </tbody>
# </table>
# -----AGE----
# <style type="text/css">
# #T_c2fb4 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_c2fb4 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_c2fb4 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_c2fb4 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_c2fb4_row0_col0, #T_c2fb4_row0_col1, #T_c2fb4_row0_col2, #T_c2fb4_row0_col3, #T_c2fb4_row0_col4, #T_c2fb4_row0_col7, #T_c2fb4_row1_col6, #T_c2fb4_row1_col7, #T_c2fb4_row1_col8, #T_c2fb4_row2_col5 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row0_col5 {
#   background-color: #2152c4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row0_col6 {
#   background-color: #f8f9fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row0_col8 {
#   background-color: #c6d3f9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row1_col0, #T_c2fb4_row1_col4 {
#   background-color: #f6f8fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row1_col1 {
#   background-color: #f7f9fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row1_col2 {
#   background-color: #f8fafd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row1_col3 {
#   background-color: #f6f8fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row1_col5 {
#   background-color: #4975f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col0 {
#   background-color: #f2f5fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col1 {
#   background-color: #d2dcf9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col2, #T_c2fb4_row2_col4 {
#   background-color: #bacaf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col3 {
#   background-color: #c4d1f9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col6 {
#   background-color: #8fa9f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col7 {
#   background-color: #7c9af6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row2_col8, #T_c2fb4_row3_col0, #T_c2fb4_row3_col1, #T_c2fb4_row3_col2, #T_c2fb4_row3_col3, #T_c2fb4_row3_col4, #T_c2fb4_row3_col5, #T_c2fb4_row3_col6, #T_c2fb4_row3_col7 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_c2fb4_row3_col8 {
#   background-color: #6a8df7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_c2fb4">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_c2fb4_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_c2fb4_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_c2fb4_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_c2fb4_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_c2fb4_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_c2fb4_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_c2fb4_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_c2fb4_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_c2fb4_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_c2fb4_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_c2fb4_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >AGE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2fb4_level0_row0" class="row_heading level0 row0" >18-29</th>
#       <td id="T_c2fb4_row0_col0" class="data row0 col0" >0.816</td>
#       <td id="T_c2fb4_row0_col1" class="data row0 col1" >0.819</td>
#       <td id="T_c2fb4_row0_col2" class="data row0 col2" >0.809</td>
#       <td id="T_c2fb4_row0_col3" class="data row0 col3" >0.829</td>
#       <td id="T_c2fb4_row0_col4" class="data row0 col4" >0.796</td>
#       <td id="T_c2fb4_row0_col5" class="data row0 col5" >0.707</td>
#       <td id="T_c2fb4_row0_col6" class="data row0 col6" >0.716</td>
#       <td id="T_c2fb4_row0_col7" class="data row0 col7" >0.765</td>
#       <td id="T_c2fb4_row0_col8" class="data row0 col8" >0.703</td>
#     </tr>
#     <tr>
#       <th id="T_c2fb4_level0_row1" class="row_heading level0 row1" >30-49</th>
#       <td id="T_c2fb4_row1_col0" class="data row1 col0" >0.812</td>
#       <td id="T_c2fb4_row1_col1" class="data row1 col1" >0.816</td>
#       <td id="T_c2fb4_row1_col2" class="data row1 col2" >0.806</td>
#       <td id="T_c2fb4_row1_col3" class="data row1 col3" >0.824</td>
#       <td id="T_c2fb4_row1_col4" class="data row1 col4" >0.792</td>
#       <td id="T_c2fb4_row1_col5" class="data row1 col5" >0.707</td>
#       <td id="T_c2fb4_row1_col6" class="data row1 col6" >0.717</td>
#       <td id="T_c2fb4_row1_col7" class="data row1 col7" >0.765</td>
#       <td id="T_c2fb4_row1_col8" class="data row1 col8" >0.705</td>
#     </tr>
#     <tr>
#       <th id="T_c2fb4_level0_row2" class="row_heading level0 row2" >50-64</th>
#       <td id="T_c2fb4_row2_col0" class="data row2 col0" >0.811</td>
#       <td id="T_c2fb4_row2_col1" class="data row2 col1" >0.811</td>
#       <td id="T_c2fb4_row2_col2" class="data row2 col2" >0.799</td>
#       <td id="T_c2fb4_row2_col3" class="data row2 col3" >0.819</td>
#       <td id="T_c2fb4_row2_col4" class="data row2 col4" >0.787</td>
#       <td id="T_c2fb4_row2_col5" class="data row2 col5" >0.710</td>
#       <td id="T_c2fb4_row2_col6" class="data row2 col6" >0.714</td>
#       <td id="T_c2fb4_row2_col7" class="data row2 col7" >0.759</td>
#       <td id="T_c2fb4_row2_col8" class="data row2 col8" >0.699</td>
#     </tr>
#     <tr>
#       <th id="T_c2fb4_level0_row3" class="row_heading level0 row3" >65+</th>
#       <td id="T_c2fb4_row3_col0" class="data row3 col0" >0.793</td>
#       <td id="T_c2fb4_row3_col1" class="data row3 col1" >0.794</td>
#       <td id="T_c2fb4_row3_col2" class="data row3 col2" >0.781</td>
#       <td id="T_c2fb4_row3_col3" class="data row3 col3" >0.802</td>
#       <td id="T_c2fb4_row3_col4" class="data row3 col4" >0.772</td>
#       <td id="T_c2fb4_row3_col5" class="data row3 col5" >0.706</td>
#       <td id="T_c2fb4_row3_col6" class="data row3 col6" >0.710</td>
#       <td id="T_c2fb4_row3_col7" class="data row3 col7" >0.754</td>
#       <td id="T_c2fb4_row3_col8" class="data row3 col8" >0.701</td>
#     </tr>
#   </tbody>
# </table>
# -----SEX----
# <style type="text/css">
# #T_16e5d th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_16e5d td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_16e5d th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_16e5d th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_16e5d_row0_col0, #T_16e5d_row0_col1, #T_16e5d_row0_col2, #T_16e5d_row0_col3, #T_16e5d_row0_col4, #T_16e5d_row0_col5, #T_16e5d_row0_col7, #T_16e5d_row1_col6, #T_16e5d_row1_col8 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_16e5d_row0_col6, #T_16e5d_row0_col8, #T_16e5d_row1_col0, #T_16e5d_row1_col1, #T_16e5d_row1_col2, #T_16e5d_row1_col3, #T_16e5d_row1_col4, #T_16e5d_row1_col5, #T_16e5d_row1_col7 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_16e5d">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_16e5d_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_16e5d_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_16e5d_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_16e5d_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_16e5d_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_16e5d_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_16e5d_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_16e5d_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_16e5d_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_16e5d_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_16e5d_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SEX</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e5d_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_16e5d_row0_col0" class="data row0 col0" >0.814</td>
#       <td id="T_16e5d_row0_col1" class="data row0 col1" >0.816</td>
#       <td id="T_16e5d_row0_col2" class="data row0 col2" >0.803</td>
#       <td id="T_16e5d_row0_col3" class="data row0 col3" >0.827</td>
#       <td id="T_16e5d_row0_col4" class="data row0 col4" >0.792</td>
#       <td id="T_16e5d_row0_col5" class="data row0 col5" >0.708</td>
#       <td id="T_16e5d_row0_col6" class="data row0 col6" >0.715</td>
#       <td id="T_16e5d_row0_col7" class="data row0 col7" >0.764</td>
#       <td id="T_16e5d_row0_col8" class="data row0 col8" >0.700</td>
#     </tr>
#     <tr>
#       <th id="T_16e5d_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_16e5d_row1_col0" class="data row1 col0" >0.808</td>
#       <td id="T_16e5d_row1_col1" class="data row1 col1" >0.811</td>
#       <td id="T_16e5d_row1_col2" class="data row1 col2" >0.801</td>
#       <td id="T_16e5d_row1_col3" class="data row1 col3" >0.818</td>
#       <td id="T_16e5d_row1_col4" class="data row1 col4" >0.788</td>
#       <td id="T_16e5d_row1_col5" class="data row1 col5" >0.708</td>
#       <td id="T_16e5d_row1_col6" class="data row1 col6" >0.717</td>
#       <td id="T_16e5d_row1_col7" class="data row1 col7" >0.761</td>
#       <td id="T_16e5d_row1_col8" class="data row1 col8" >0.704</td>
#     </tr>
#   </tbody>
# </table>
# -----EDUCATION----
# <style type="text/css">
# #T_7a529 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_7a529 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_7a529 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_7a529 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_7a529_row0_col0, #T_7a529_row0_col1, #T_7a529_row0_col2, #T_7a529_row0_col3, #T_7a529_row0_col4, #T_7a529_row0_col6, #T_7a529_row1_col5, #T_7a529_row5_col7, #T_7a529_row5_col8 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row0_col5 {
#   background-color: #fdfdfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row0_col7, #T_7a529_row0_col8, #T_7a529_row1_col6, #T_7a529_row5_col0, #T_7a529_row5_col1, #T_7a529_row5_col2, #T_7a529_row5_col3, #T_7a529_row5_col4, #T_7a529_row5_col5 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col0 {
#   background-color: #eaeefb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col1 {
#   background-color: #c2d0f8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col2 {
#   background-color: #7b99f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col3 {
#   background-color: #e6ecfa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col4 {
#   background-color: #b0c2f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col7 {
#   background-color: #5981f8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row1_col8 {
#   background-color: #3664e0;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col0 {
#   background-color: #acbff7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col1 {
#   background-color: #a2b7f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col2 {
#   background-color: #c4d1f9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col3 {
#   background-color: #bfcdf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col4 {
#   background-color: #b5c6f8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col5 {
#   background-color: #d7e0fa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col6 {
#   background-color: #f2f5fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col7 {
#   background-color: #e8edfb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row2_col8 {
#   background-color: #819ef5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col0 {
#   background-color: #96aef6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col1 {
#   background-color: #839ff5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col2 {
#   background-color: #809df5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col3 {
#   background-color: #a7bbf7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col4 {
#   background-color: #99b0f6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col5 {
#   background-color: #8fa9f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col6 {
#   background-color: #2b5bd1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col7 {
#   background-color: #c9d5f9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row3_col8 {
#   background-color: #7c9af6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col0, #T_7a529_row4_col1 {
#   background-color: #416ef0;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col2 {
#   background-color: #3e6beb;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col3 {
#   background-color: #4c77f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col4 {
#   background-color: #426ff1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col5 {
#   background-color: #7293f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col6 {
#   background-color: #7f9cf5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col7 {
#   background-color: #fdfefe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row4_col8 {
#   background-color: #f3f6fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_7a529_row5_col6 {
#   background-color: #1043ac;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_7a529">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_7a529_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_7a529_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_7a529_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_7a529_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_7a529_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_7a529_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_7a529_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_7a529_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_7a529_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_7a529_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_7a529_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >EDUCATION</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a529_level0_row0" class="row_heading level0 row0" >Less than high school</th>
#       <td id="T_7a529_row0_col0" class="data row0 col0" >0.829</td>
#       <td id="T_7a529_row0_col1" class="data row0 col1" >0.830</td>
#       <td id="T_7a529_row0_col2" class="data row0 col2" >0.813</td>
#       <td id="T_7a529_row0_col3" class="data row0 col3" >0.837</td>
#       <td id="T_7a529_row0_col4" class="data row0 col4" >0.802</td>
#       <td id="T_7a529_row0_col5" class="data row0 col5" >0.712</td>
#       <td id="T_7a529_row0_col6" class="data row0 col6" >0.717</td>
#       <td id="T_7a529_row0_col7" class="data row0 col7" >0.751</td>
#       <td id="T_7a529_row0_col8" class="data row0 col8" >0.688</td>
#     </tr>
#     <tr>
#       <th id="T_7a529_level0_row1" class="row_heading level0 row1" >High school graduate</th>
#       <td id="T_7a529_row1_col0" class="data row1 col0" >0.818</td>
#       <td id="T_7a529_row1_col1" class="data row1 col1" >0.817</td>
#       <td id="T_7a529_row1_col2" class="data row1 col2" >0.801</td>
#       <td id="T_7a529_row1_col3" class="data row1 col3" >0.827</td>
#       <td id="T_7a529_row1_col4" class="data row1 col4" >0.792</td>
#       <td id="T_7a529_row1_col5" class="data row1 col5" >0.713</td>
#       <td id="T_7a529_row1_col6" class="data row1 col6" >0.715</td>
#       <td id="T_7a529_row1_col7" class="data row1 col7" >0.757</td>
#       <td id="T_7a529_row1_col8" class="data row1 col8" >0.693</td>
#     </tr>
#     <tr>
#       <th id="T_7a529_level0_row2" class="row_heading level0 row2" >Some college, no degree</th>
#       <td id="T_7a529_row2_col0" class="data row2 col0" >0.813</td>
#       <td id="T_7a529_row2_col1" class="data row2 col1" >0.815</td>
#       <td id="T_7a529_row2_col2" class="data row2 col2" >0.805</td>
#       <td id="T_7a529_row2_col3" class="data row2 col3" >0.824</td>
#       <td id="T_7a529_row2_col4" class="data row2 col4" >0.792</td>
#       <td id="T_7a529_row2_col5" class="data row2 col5" >0.708</td>
#       <td id="T_7a529_row2_col6" class="data row2 col6" >0.717</td>
#       <td id="T_7a529_row2_col7" class="data row2 col7" >0.763</td>
#       <td id="T_7a
# -----CITIZEN----
# <style type="text/css">
# #T_84698 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_84698 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_84698 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_84698 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_84698_row0_col0, #T_84698_row0_col3, #T_84698_row0_col5, #T_84698_row0_col7, #T_84698_row1_col1, #T_84698_row1_col2, #T_84698_row1_col4, #T_84698_row1_col6, #T_84698_row1_col8 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_84698_row0_col1, #T_84698_row0_col2, #T_84698_row0_col4, #T_84698_row0_col6, #T_84698_row0_col8, #T_84698_row1_col0, #T_84698_row1_col3, #T_84698_row1_col5, #T_84698_row1_col7 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_84698">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_84698_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_84698_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_84698_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_84698_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_84698_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_84698_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_84698_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_84698_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_84698_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_84698_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_84698_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CITIZEN</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84698_level0_row0" class="row_heading level0 row0" >Yes</th>
#       <td id="T_84698_row0_col0" class="data row0 col0" >0.813</td>
#       <td id="T_84698_row0_col1" class="data row0 col1" >0.815</td>
#       <td id="T_84698_row0_col2" class="data row0 col2" >0.804</td>
#       <td id="T_84698_row0_col3" class="data row0 col3" >0.824</td>
#       <td id="T_84698_row0_col4" class="data row0 col4" >0.791</td>
#       <td id="T_84698_row0_col5" class="data row0 col5" >0.709</td>
#       <td id="T_84698_row0_col6" class="data row0 col6" >0.716</td>
#       <td id="T_84698_row0_col7" class="data row0 col7" >0.764</td>
#       <td id="T_84698_row0_col8" class="data row0 col8" >0.703</td>
#     </tr>
#     <tr>
#       <th id="T_84698_level0_row1" class="row_heading level0 row1" >No</th>
#       <td id="T_84698_row1_col0" class="data row1 col0" >0.806</td>
#       <td id="T_84698_row1_col1" class="data row1 col1" >0.818</td>
#       <td id="T_84698_row1_col2" class="data row1 col2" >0.813</td>
#       <td id="T_84698_row1_col3" class="data row1 col3" >0.819</td>
#       <td id="T_84698_row1_col4" class="data row1 col4" >0.799</td>
#       <td id="T_84698_row1_col5" class="data row1 col5" >0.702</td>
#       <td id="T_84698_row1_col6" class="data row1 col6" >0.718</td>
#       <td id="T_84698_row1_col7" class="data row1 col7" >0.753</td>
#       <td id="T_84698_row1_col8" class="data row1 col8" >0.708</td>
#     </tr>
#   </tbody>
# </table>
# -----MARITAL----
# <style type="text/css">
# #T_3c465 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_3c465 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_3c465 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_3c465 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_3c465_row0_col0 {
#   background-color: #8fa9f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col1 {
#   background-color: #96aef6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col2 {
#   background-color: #bdccf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col3 {
#   background-color: #acbff7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col4 {
#   background-color: #7d9bf5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col5 {
#   background-color: #4370f3;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col6 {
#   background-color: #7696f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col7 {
#   background-color: #b5c6f8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row0_col8 {
#   background-color: #f7f9fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col0 {
#   background-color: #bacaf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col1 {
#   background-color: #839ff5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col2 {
#   background-color: #829ef5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col3 {
#   background-color: #7e9cf5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col4 {
#   background-color: #7495f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col5, #T_3c465_row4_col0, #T_3c465_row4_col1, #T_3c465_row4_col2, #T_3c465_row4_col3, #T_3c465_row4_col4, #T_3c465_row4_col6, #T_3c465_row4_col7, #T_3c465_row4_col8 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col6 {
#   background-color: #f4f6fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col7 {
#   background-color: #aec0f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row1_col8 {
#   background-color: #658af7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col0 {
#   background-color: #a7bbf7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col1 {
#   background-color: #edf1fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col2 {
#   background-color: #e8edfb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col3 {
#   background-color: #84a0f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col4 {
#   background-color: #8da7f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col5, #T_3c465_row3_col0, #T_3c465_row3_col1, #T_3c465_row3_col2, #T_3c465_row3_col3, #T_3c465_row3_col4, #T_3c465_row3_col6, #T_3c465_row3_col7, #T_3c465_row3_col8 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col6 {
#   background-color: #f1f4fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col7 {
#   background-color: #1f51c1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row2_col8 {
#   background-color: #1547b3;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row3_col5 {
#   background-color: #6387f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3c465_row4_col5 {
#   background-color: #f2f4fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_3c465">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_3c465_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_3c465_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_3c465_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_3c465_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_3c465_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_3c465_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_3c465_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_3c465_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_3c465_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_3c465_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_3c465_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MARITAL</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c465_level0_row0" class="row_heading level0 row0" >Married</th>
#       <td id="T_3c465_row0_col0" class="data row0 col0" >0.809</td>
#       <td id="T_3c465_row0_col1" class="data row0 col1" >0.812</td>
#       <td id="T_3c465_row0_col2" class="data row0 col2" >0.801</td>
#       <td id="T_3c465_row0_col3" class="data row0 col3" >0.821</td>
#       <td id="T_3c465_row0_col4" class="data row0 col4" >0.787</td>
#       <td id="T_3c465_row0_col5" class="data row0 col5" >0.708</td>
#       <td id="T_3c465_row0_col6" class="data row0 col6" >0.715</td>
#       <td id="T_3c465_row0_col7" class="data row0 col7" >0.762</td>
#       <td id="T_3c465_row0_col8" class="data row0 col8" >0.702</td>
#     </tr>
#     <tr>
#       <th id="T_3c465_level0_row1" class="row_heading level0 row1" >Divorced</th>
#       <td id="T_3c465_row1_col0" class="data row1 col0" >0.811</td>
#       <td id="T_3c465_row1_col1" class="data row1 col1" >0.811</td>
#       <td id="T_3c465_row1_col2" class="data row1 col2" >0.798</td>
#       <td id="T_3c465_row1_col3" class="data row1 col3" >0.819</td>
#       <td id="T_3c465_row1_col4" class="data row1 col4" >0.787</td>
#       <td id="T_3c465_row1_col5" class="data row1 col5" >0.711</td>
#       <td id="T_3c465_row1_col6" class="data row1 col6" >0.717</td>
#       <td id="T_3c465_row1_col7" class="data row1 col7" >0.762</td>
#       <td id="T_3c465_row1_col8" class="data row1 col8" >0.699</td>
#     </tr>
#     <tr>
#       <th id="T_3c465_level0_row2" class="row_heading level0 row2" >Separated</th>
#       <td id="T_3c465_row2_col0" class="data row2 col0" >0.810</td>
#       <td id="T_3c465_row2_col1" class="data row2 col1" >0.816</td>
#       <td id="T_3c465_row2_col2" class="data row2 col2" >0.803</td>
#       <td id="T_3c465_row2_col3" class="data row2 col3" >0.819</td>
#       <td id="T_3c465_row2_col4" class="data row2 col4" >0.788</td>
#       <td id="T_3c465_row2_col5" class="data row2 col5" >0.707</td>
#       <td id="T_3c465_row2_col6" class="data row2 col6" >0.716</td>
#       <td id="T_3c465_row2_col7" class="data row2 col7" >0.755</td>
#       <td id="T_3c465_row2_col8" class="data row2 col8" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_3c465_level0_row3" class="row_heading level0 row3" >Widowed</th>
#       <td id="T_3c465_row3_col0" class="data row3 col0" >0.801</td>
#       <td id="T_3c465_row3_col1" class="data row3 col1" >0.801</td>
#       <td id="T_3c465_row3_col2" class="data row3 col2" >0.786</td>
#       <td id="T_3c465_row3_col3" class="data row3 col3" >0.809</td>
#       <td id="T_3c465_row3_col4" class="data row3 col4" >0.779</td>
#       <td id="T_3c465_row3_col5" class="data row3 col5" >0.709</td>
#       <td id="T_3c465_row3_col6" class="data row3 col6" >0.712</td>
#       <td id="T_3c465_row3_col7" class="data row3 col7" >0.753</td>
#       <td id="T_3c465_row3_col8" class="data row3 col8" >0.697</td>
#     </tr>
#     <tr>
#       <th
# -----RELIG----
# <style type="text/css">
# #T_fabde th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_fabde td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_fabde th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_fabde th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_fabde_row0_col0 {
#   background-color: #fcfdfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col1 {
#   background-color: #f7f9fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col2, #T_fabde_row10_col7 {
#   background-color: #f4f6fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col3 {
#   background-color: #fafbfd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col4 {
#   background-color: #f8f9fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col5 {
#   background-color: #fdfdfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col6, #T_fabde_row8_col7, #T_fabde_row8_col8 {
#   background-color: #f9fafd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col7 {
#   background-color: #bfcdf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row0_col8, #T_fabde_row8_col0 {
#   background-color: #184ab7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row1_col0, #T_fabde_row1_col3, #T_fabde_row1_col6 {
#   background-color: #fefeff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row1_col1, #T_fabde_row1_col2, #T_fabde_row1_col4, #T_fabde_row9_col6, #T_fabde_row9_col7, #T_fabde_row9_col8, #T_fabde_row11_col0, #T_fabde_row11_col3, #T_fabde_row11_col5, #T_fabde_row11_col6 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row1_col5 {
#   background-color: #fbfcfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row1_col7 {
#   background-color: #eff2fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row1_col8, #T_fabde_row9_col4 {
#   background-color: #6387f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col0 {
#   background-color: #7595f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col1 {
#   background-color: #658af7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col2, #T_fabde_row6_col2 {
#   background-color: #5b82f8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col3 {
#   background-color: #7d9bf5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col4 {
#   background-color: #7091f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col5, #T_fabde_row4_col8 {
#   background-color: #a5baf7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col6, #T_fabde_row4_col2 {
#   background-color: #8da7f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col7 {
#   background-color: #9bb2f6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row2_col8, #T_fabde_row3_col5 {
#   background-color: #2c5cd3;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row3_col0, #T_fabde_row3_col1, #T_fabde_row3_col2, #T_fabde_row3_col3, #T_fabde_row3_col4, #T_fabde_row3_col6, #T_fabde_row3_col8, #T_fabde_row6_col5, #T_fabde_row7_col7 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row3_col7 {
#   background-color: #1c4dbc;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col0, #T_fabde_row8_col6 {
#   background-color: #85a1f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col1, #T_fabde_row10_col3 {
#   background-color: #7797f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col3 {
#   background-color: #7495f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col4 {
#   background-color: #839ff5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col5, #T_fabde_row7_col4 {
#   background-color: #a2b7f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col6 {
#   background-color: #aec0f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row4_col7 {
#   background-color: #dfe6fa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col0 {
#   background-color: #5c83f8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col1 {
#   background-color: #7e9cf5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col2 {
#   background-color: #b1c3f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col3 {
#   background-color: #4975f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col4 {
#   background-color: #94adf6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col5 {
#   background-color: #1446b1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col6 {
#   background-color: #688cf7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col7, #T_fabde_row6_col3 {
#   background-color: #1245af;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row5_col8, #T_fabde_row7_col3 {
#   background-color: #3765e1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row6_col0 {
#   background-color: #0e41a9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row6_col1, #T_fabde_row6_col6 {
#   background-color: #3e6beb;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row6_col4 {
#   background-color: #517af8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row6_col7 {
#   background-color: #7696f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row6_col8 {
#   background-color: #d7e0fa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row7_col0 {
#   background-color: #3462dd;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row7_col1 {
#   background-color: #96aef6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row7_col2 {
#   background-color: #e5eafa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row7_col5 {
#   background-color: #1346b0;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row7_col6 {
#   background-color: #4572f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row7_col8 {
#   background-color: #aabef7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row8_col1 {
#   background-color: #1043ac;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row8_col2 {
#   background-color: #3a68e5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row8_col3 {
#   background-color: #1b4cbb;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row8_col4 {
#   background-color: #3664e0;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row8_col5 {
#   background-color: #426ff1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row9_col0, #T_fabde_row11_col8 {
#   background-color: #507af8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row9_col1 {
#   background-color: #4f79f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row9_col2 {
#   background-color: #7293f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row9_col3 {
#   background-color: #537cf8;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row9_col5 {
#   background-color: #99b0f6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col0 {
#   background-color: #88a3f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col1 {
#   background-color: #819ef5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col2 {
#   background-color: #bccbf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col4 {
#   background-color: #9fb4f6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col5 {
#   background-color: #8aa5f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col6 {
#   background-color: #e8edfb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row10_col8 {
#   background-color: #6d8ff7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_fabde_row11_col1 {
#   background-color: #fdfeff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row11_col2, #T_fabde_row11_col4 {
#   background-color: #fafbfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_fabde_row11_col7 {
#   background-color: #f8fafd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_fabde">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_fabde_level0_col0" cla
# -----RELIGATTEND----
# <style type="text/css">
# #T_3669c th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_3669c td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_3669c th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_3669c th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_3669c_row0_col0 {
#   background-color: #4c77f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row0_col1 {
#   background-color: #2354c7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row0_col2, #T_3669c_row0_col5, #T_3669c_row0_col6, #T_3669c_row0_col7, #T_3669c_row0_col8, #T_3669c_row5_col0, #T_3669c_row5_col1, #T_3669c_row5_col3, #T_3669c_row5_col4 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row0_col3 {
#   background-color: #1c4ebd;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row0_col4 {
#   background-color: #2556c9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row1_col0 {
#   background-color: #7192f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row1_col1 {
#   background-color: #7091f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row1_col2 {
#   background-color: #5f85f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row1_col3 {
#   background-color: #6085f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_3669c_row1_col4 {
#   background-color: #698cf7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# ...
# #T_004c2 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_004c2 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_004c2 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_004c2 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_004c2_row0_col0 {
#   background-color: #f6f8fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row0_col1 {
#   background-color: #6c8ef7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row0_col2, #T_004c2_row0_col6, #T_004c2_row0_col7, #T_004c2_row0_col8, #T_004c2_row4_col0, #T_004c2_row4_col1, #T_004c2_row4_col3, #T_004c2_row4_col4, #T_004c2_row4_col5 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row0_col3 {
#   background-color: #c2d0f8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row0_col4 {
#   background-color: #2d5cd4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row0_col5 {
#   background-color: #ebf0fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col0 {
#   background-color: #d2dcf9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col1 {
#   background-color: #668af7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col2 {
#   background-color: #1c4dbc;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col3 {
#   background-color: #aec0f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col4 {
#   background-color: #3b68e7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col5, #T_004c2_row2_col0, #T_004c2_row2_col1, #T_004c2_row2_col2, #T_004c2_row2_col3, #T_004c2_row2_col4, #T_004c2_row2_col5, #T_004c2_row2_col6, #T_004c2_row3_col7, #T_004c2_row3_col8 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col6 {
#   background-color: #84a0f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col7 {
#   background-color: #7091f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row1_col8 {
#   background-color: #6488f7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row2_col7 {
#   background-color: #f8fafd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row2_col8 {
#   background-color: #edf1fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col0 {
#   background-color: #3e6beb;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col1 {
#   background-color: #426ff1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col2 {
#   background-color: #6a8df7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col3 {
#   background-color: #4370f3;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col4 {
#   background-color: #4874f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col5 {
#   background-color: #6d8ff7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row3_col6 {
#   background-color: #fcfdfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row4_col2 {
#   background-color: #2e5dd5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_004c2_row4_col6 {
#   background-color: #aabef7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row4_col7 {
#   background-color: #f5f7fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_004c2_row4_col8 {
#   background-color: #f6f8fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_004c2">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_004c2_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_004c2_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_004c2_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_004c2_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_004c2_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_004c2_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_004c2_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_004c2_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_004c2_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_004c2_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_004c2_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >POLIDEOLOGY</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_004c2_level0_row0" class="row_heading level0 row0" >Very conservative</th>
#       <td id="T_004c2_row0_col0" class="data row0 col0" >0.806</td>
#       <td id="T_004c2_row0_col1" class="data row0 col1" >0.798</td>
#       <td id="T_004c2_row0_col2" class="data row0 col2" >0.780</td>
#       <td id="T_004c2_row0_col3" class="data row0 col3" >0.813</td>
#       <td id="T_004c2_row0_col4" class="data row0 col4" >0.773</td>
#       <td id="T_004c2_row0_col5" class="data row0 col5" >0.704</td>
#       <td id="T_004c2_row0_col6" class="data row0 col6" >0.700</td>
#       <td id="T_004c2_row0_col7" class="data row0 col7" >0.735</td>
#       <td id="T_004c2_row0_col8" class="data row0 col8" >0.665</td>
#     </tr>
#     <tr>
#       <th id="T_004c2_level0_row1" class="row_heading level0 row1" >Conservative</th>
#       <td id="T_004c2_row1_col0" class="data row1 col0" >0.802</td>
#       <td id="T_004c2_row1_col1" class="data row1 col1" >0.798</td>
#       <td id="T_004c2_row1_col2" class="data row1 col2" >0.782</td>
#       <td id="T_004c2_row1_col3" class="data row1 col3" >0.811</td>
#       <td id="T_004c2_row1_col4" class="data row1 col4" >0.774</td>
#       <td id="T_004c2_row1_col5" class="data row1 col5" >0.709</td>
#       <td id="T_004c2_row1_col6" class="data row1 col6" >0.709</td>
#       <td id="T_004c2_row1_col7" class="data row1 col7" >0.749</td>
#       <td id="T_004c2_row1_col8" class="data row1 col8" >0.686</td>
#     </tr>
#     <tr>
#       <th id="T_004c2_level0_row2" class="row_heading level0 row2" >Moderate</th>
#       <td id="T_004c2_row2_col0" class="data row2 col0" >0.811</td>
#       <td id="T_004c2_row2_col1" class="data row2 col1" >0.815</td>
#       <td id="T_004c2_row2_col2" class="data row2 col2" >0.805</td>
#       <td id="T_004c2_row2_col3" class="data row2 col3" >0.823</td>
#       <td id="T_004c2_row2_col4" class="data row2 col4" >0.793</td>
#       <td id="T_004c2_row2_col5" class="data row2 col5" >0.709</td>
#       <td id="T_004c2_row2_col6" class="data row2 col6" >0.719</td>
#       <td id="T_004c2_row2_col7" class="data row2 col7" >0.764</td>
#       <td id="T_004c2_row2_col8" class="data row2 col8" >0.708</td>
#     </tr>
#     <tr>
#       <th id="T_004c2_level0_row3" class="row_heading level0 row3" >Liberal</th>
#       <td id="T_004c2_row3_col0" class="data row3 col0" >0.788</td>
#       <td id="T_004c2_row3_col1" class="data row3 col1" >0.794</td>
#       <td id="T_004c2_row3_col2" class="data row3 col2" >0.790</td>
#       <td id="T_004c2_row3_col3" class="data row3 col3" >0.800</td>
#       <td id="T_004c2_row3_col4" class="data row3 col4" >0.776</td>
#       <td id="T_004c2_row3_col5" class="data row3 col5" >0.698</td>
#       <td id="T_004c2_row3_col6" class="data row3 col6" >0.718</td>
#       <td id="T_004c2_row3_col7" class="data row3 col7" >0.768</td>
#       <td id="T_004c2_row3_col8" class="data row3 col8" >0.723</td>
#     </tr>
#     <tr>
#       <th id="T_004c2_level0_row4" class="row_heading level0 ro
# -----RACE----
# <style type="text/css">
# #T_af2a6 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_af2a6 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_af2a6 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_af2a6 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_af2a6_row0_col0 {
#   background-color: #85a1f5;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col1 {
#   background-color: #4d78f9;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col2 {
#   background-color: #6c8ef7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col3 {
#   background-color: #a5baf7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col4 {
#   background-color: #7495f6;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col5, #T_af2a6_row0_col7, #T_af2a6_row1_col0, #T_af2a6_row1_col1, #T_af2a6_row1_col2, #T_af2a6_row2_col8, #T_af2a6_row3_col3, #T_af2a6_row3_col4, #T_af2a6_row3_col6 {
#   background-color: #ffffff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col6 {
#   background-color: #eff2fb;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row0_col8 {
#   background-color: #d2dcf9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row1_col3 {
#   background-color: #fafbfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row1_col4, #T_af2a6_row3_col2 {
#   background-color: #fdfdfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row1_col5 {
#   background-color: #658af7;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_af2a6_row1_col6 {
#   background-color: #f7f9fd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row1_col7 {
#   background-color: #bdccf8;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row1_col8, #T_af2a6_row2_col2 {
#   background-color: #f4f6fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col0 {
#   background-color: #91aaf6;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col1 {
#   background-color: #c6d3f9;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col3 {
#   background-color: #d9e1fa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col4 {
#   background-color: #f4f7fc;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col5 {
#   background-color: #1446b1;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col6 {
#   background-color: #f9fafd;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row2_col7 {
#   background-color: #dce4fa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row3_col0 {
#   background-color: #fdfefe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row3_col1 {
#   background-color: #fefeff;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row3_col5 {
#   background-color: #b1c3f7;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row3_col7 {
#   background-color: #dee5fa;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row3_col8 {
#   background-color: #fbfcfe;
#   color: #000000;
#   font-size: 1.3rem;
# }
# #T_af2a6_row4_col0, #T_af2a6_row4_col1, #T_af2a6_row4_col2, #T_af2a6_row4_col3, #T_af2a6_row4_col4, #T_af2a6_row4_col5, #T_af2a6_row4_col6, #T_af2a6_row4_col7, #T_af2a6_row4_col8 {
#   background-color: #0a3ea4;
#   color: #f1f1f1;
#   font-size: 1.3rem;
# }
# </style>
# <table id="T_af2a6">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_af2a6_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_af2a6_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_af2a6_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_af2a6_level1_col1" class="col_heading level1 col1" >j1-jumbo</th>
#       <th id="T_af2a6_level1_col2" class="col_heading level1 col2" >j1-grande-v2-beta</th>
#       <th id="T_af2a6_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_af2a6_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_af2a6_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_af2a6_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_af2a6_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_af2a6_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RACE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af2a6_level0_row0" class="row_heading level0 row0" >White</th>
#       <td id="T_af2a6_row0_col0" class="data row0 col0" >0.807</td>
#       <td id="T_af2a6_row0_col1" class="data row0 col1" >0.808</td>
#       <td id="T_af2a6_row0_col2" class="data row0 col2" >0.796</td>
#       <td id="T_af2a6_row0_col3" class="data row0 col3" >0.818</td>
#       <td id="T_af2a6_row0_col4" class="data row0 col4" >0.785</td>
#       <td id="T_af2a6_row0_col5" class="data row0 col5" >0.710</td>
#       <td id="T_af2a6_row0_col6" class="data row0 col6" >0.715</td>
#       <td id="T_af2a6_row0_col7" class="data row0 col7" >0.763</td>
#       <td id="T_af2a6_row0_col8" class="data row0 col8" >0.701</td>
#     </tr>
#     <tr>
#       <th id="T_af2a6_level0_row1" class="row_heading level0 row1" >Black</th>
#       <td id="T_af2a6_row1_col0" class="data row1 col0" >0.814</td>
#       <td id="T_af2a6_row1_col1" class="data row1 col1" >0.822</td>
#       <td id="T_af2a6_row1_col2" class="data row1 col2" >0.813</td>
#       <td id="T_af2a6_row1_col3" class="data row1 col3" >0.824</td>
#       <td id="T_af2a6_row1_col4" class="data row1 col4" >0.798</td>
#       <td id="T_af2a6_row1_col5" class="data row1 col5" >0.703</td>
#       <td id="T_af2a6_row1_col6" class="data row1 col6" >0.717</td>
#       <td id="T_af2a6_row1_col7" class="data row1 col7" >0.755</td>
#       <td id="T_af2a6_row1_col8" class="data row1 col8" >0.704</td>
#     </tr>
#     <tr>
#       <th id="T_af2a6_level0_row2" class="row_heading level0 row2" >Asian</th>
#       <td id="T_af2a6_row2_col0" class="data row2 col0" >0.808</td>
#       <td id="T_af2a6_row2_col1" class="data row2 col1" >0.815</td>
#       <td id="T_af2a6_row2_col2" class="data row2 col2" >0.807</td>
#       <td id="T_af2a6_row2_col3" class="data row2 col3" >0.820</td>
#       <td id="T_af2a6_row2_col4" class="data row2 col4" >0.794</td>
#       <td id="T_af2a6_row2_col5" class="data row2 col5" >0.699</td>
#       <td id="T_af2a6_row2_col6" class="data row2 col6" >0.717</td>
#       <td id="T_af2a6_row2_col7" class="data row2 col7" >0.757</td>
#       <td id="T_af2a6_row2_col8" class="data row2 col8" >0.710</td>
#     </tr>
#     <tr>
#       <th id="T_af2a6_level0_row3" class="row_heading level0 row3" >Hispanic</th>
#       <td id="T_af2a6_row3_col0" class="data row3 col0" >0.814</td>
#       <td id="T_af2a6_row3_col1" class="data row3 col1" >0.821</td>
#       <td id="T_af2a6_row3_col2" class="data row3 col2" >0.812</td>
#       <td id="T_af2a6_row3_col3" class="data row3 col3" >0.826</td>
#       <td id="T_af2a6_row3_col4" class="data row3 col4" >0.799</td>
#       <td id="T_af2a6_row3_col5" class="data row3 col5" >0.705</td>
#       <td id="T_af2a6_row3_col6" class="data row3 col6" >0.719</td>
#       <td id="T_af2a6_row3_col7" class="data row3 col7" >0.757</td>
#       <td id="T_af2a6_row3_col8" class="data row3 col8" >0.708</td>
#     </tr>
#     <tr>
#       <th id="T_af2a6_level0_row4" class="row_heading level0 row4" >Other</th>
#       <td id="T_af2a6_row4_col0" class="data row4 col0" >0.800</td>
#       <td id="T
